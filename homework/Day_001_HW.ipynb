# %%
# 載入基礎套件與代稱
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# 定義 mean_squared_error 這個函數, 計算並傳回 MSE
def mean_squared_error(y, yp):
    """
    請完成這個 Function 後往下執行
    """
    mse = sum((y-yp)**2) / len(y)
    return mse

# %%
# 與範例相同, 不另外解說
w = 3
b = 0.5
x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
# 與範例相同, 不另外解說
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 211.953
# The Mean absolute error is 11.305

# %% [markdown]
# # [作業2]
#
# **請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：**
#
# $\Rightarrow$我選得資料：Gas Prices in Brazil。
#
# **1. 你選的這組資料為何重要**
#
# $\Rightarrow$油價可以影響的面相非常廣，利息、民生消費、股市、貨幣、產業都會受到影響，所以了解各地區的油價，有利於政府對於政策制定上的考量。
#
# **2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)**
#
# $\Rightarrow$由巴西國家石油管理局ANP所提供。
#
# **3. 蒐集而來的資料型態為何**
#
# $\Rightarrow$.tsv格式。.csv的一種變體，都屬於結構化資料，主要在於分隔的方式不一樣，但是都可以用excel開啟。
#
# **4. 這組資料想解決的問題如何評估**
#
# $\Rightarrow$這組資料是要依照各地區的油價趨向做出相應的政策，所以必須對應不同的地區做迴歸分析，而迴歸分析的指標可以用MAE判斷我們預估數值的可信度。
#
# # [作業3]
#
# **想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：**
#
# **1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)**
#
# $\Rightarrow$假定車隊業績來源只有載客，沒有其餘業外收入(廣告)，並且趟數不影響業績，代表只有有載客的里程數會影響主要收益(載客里程數與淨收入成正比)，所以核心問題就會為：如何提高載客里程數，或是如何降低空車率(車上沒人/一天有營業的時間)。
#
# **2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)**
#
# $\Rightarrow$會影響車上有沒有人的因素，假定有包括車隊的形象(整潔、司機專業度)，及載客地點，或是叫車方便性。而以上資料可以由制定的問卷、評價系統從乘客方面蒐集，並且蒐集各地乘客叫車熱區(由政府開放資料或是與同業合作)。
#
# **3. 蒐集而來的資料型態為何**
#
# $\Rightarrow$結構化資料。
#
# **4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)**
#
# $\Rightarrow$假定形象、地點、方便性為主要影響空車率的因素，那麼可以運用迴歸分析，並且以MAE作為預估指標，判斷假設與預估值是否有極高的可信度。
